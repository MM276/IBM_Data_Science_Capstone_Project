# %% [markdown]
# ### Introduction/Business Problem

# %% [markdown]
# The goal of this project is to determine if there is a correlation between neighborhood composition in terms of restaurants, outdoor activities, and economic specialties and the impact of COVID-19 on those neighborhoods.  I will do a clustering very similar to the one we did for Toronto and New York, then add a dimension of COVID rates and overall population to determine if certain neighborhoods were disproportionately affected, and if so, which ones. I'll also try to determine what economic factors may have contributed to those case rates if a correlation is found.
#
# Another interesting experiment may be to also run clustering INCLUDING scaled COVID data (ie, by percent of population affected) to see if we get a different grouping of neigborhoods.
#
# The target audience for this report may be municipalities or local governments preparing for pandemic scenarios in the future, to determine the highest likelihood areas of spread and which activities may need to be limited first.  It may also indicate who the most at risk people and businesses are - and hence what kinds of businesses and areas need to close or distance first.
#
# The challenge/assumption here is that people actually *live* in the neighborhoods where they work and where certain kinds of businesses are located.  It may also be that crowds are more likely to bring COVID to high traffic areas either way. I'm curious to see the outcome.

# %% [markdown]
# ### Data and Methods

# %% [markdown]
# For COVID case rate data, I will use data publicly available on the LA county website, and only focus on LA counties.  http://publichealth.lacounty.gov/media/coronavirus/locations.htm
#
# For the geographical coordinates of those counties, I will rely on USC's neighborhood data for social change, located here, which can be exported as a CSV:
# https://usc.data.socrata.com/dataset/Los-Angeles-Neighborhood-Map/r8qd-yxsr
#
# I will only be focused on neighborhoods in Los Angeles as opposed to the surrounding suburbs and exurbs.  I will simply filter neighborhood data from the public health website for LA county on neighborhoods containing "Los Angeles."
#
# To determine the clusters of similar neighborhoods with which to pair COVID data, I will use the FourSquare API in a manner similar to the previous exercises (ie, cluster by neighborhood using one-hot encoding) and include COVID case rate data to see if we get obvious clusters by economic driver.

# %% [markdown]
# ### Quick Data Gathering Exercise: COVID in LA

# %%
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium 
import geocoder

# %%
url = "http://publichealth.lacounty.gov/media/coronavirus/locations.htm"
tables_from_page = pd.read_html(url)

# %%
covid_by_neighborhood = tables_from_page[4]

# %%
los_angeles_covid_rates = covid_by_neighborhood[covid_by_neighborhood["City/Community"].str.contains("Los Angeles -")]

# %%
los_angeles_covid_rates
# Out:
#                             City/Community  Total Cases  Crude Case Rate3  \
# 85           Los Angeles - Adams-Normandie           50               610
# 86                    Los Angeles - Alsace           37               297
# 87   Los Angeles - Angeles National Forest            0                 0
# 88          Los Angeles - Angelino Heights           14               560
# 89                    Los Angeles - Arleta          318               925
# ..                                     ...          ...               ...
# 219       Los Angeles - Wholesale District          167               462
# 220               Los Angeles - Wilmington          360               637
# 221          Los Angeles - Wilshire Center          298               594
# 222                 Los Angeles - Winnetka          314               606
# 223           Los Angeles - Woodland Hills          258               379
#
#      Adjusted Case Rate3,4 Unstable Adjusted Rate  2018 PEPS Population
# 85                     589                    NaN                  8202
# 86                     302                    NaN                 12445
# 87                       0                    NaN                    40
# 88                     614                      ^                  2502
# 89                     924                    NaN                 34370
# ..                     ...                    ...                   ...
# 219                    461                    NaN                 36129
# 220                    633                    NaN                 56487
# 221                    591                    NaN                 50170
# 222                    598                    NaN                 51786
# 223                    383                    NaN                 68055
#
# [139 rows x 6 columns]

# %% [markdown]
# ### Quick Data Gathering Exercise: LA Neighborhood Data

# %%
los_angeles_covid_rates["City/Community"]=los_angeles_covid_rates["City/Community"].str.split(" - ").str[1]
# Out:
# <ipython-input-35-9167466dba61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   los_angeles_covid_rates["City/Community"]=los_angeles_covid_rates["City/Community"].str.split(" - ").str[1]

# %%
los_angeles_covid_rates
# Out:
#               City/Community  Total Cases  Crude Case Rate3  \
# 85           Adams-Normandie           50               610
# 86                    Alsace           37               297
# 87   Angeles National Forest            0                 0
# 88          Angelino Heights           14               560
# 89                    Arleta          318               925
# ..                       ...          ...               ...
# 219       Wholesale District          167               462
# 220               Wilmington          360               637
# 221          Wilshire Center          298               594
# 222                 Winnetka          314               606
# 223           Woodland Hills          258               379
#
#      Adjusted Case Rate3,4 Unstable Adjusted Rate  2018 PEPS Population
# 85                     589                    NaN                  8202
# 86                     302                    NaN                 12445
# 87                       0                    NaN                    40
# 88                     614                      ^                  2502
# 89                     924                    NaN                 34370
# ..                     ...                    ...                   ...
# 219                    461                    NaN                 36129
# 220                    633                    NaN                 56487
# 221                    591                    NaN                 50170
# 222                    598                    NaN                 51786
# 223                    383                    NaN                 68055
#
# [139 rows x 6 columns]

# %%
la_neighborhoods=pd.read_csv('la_neighborhoods.csv')

# %%
la_neighborhoods
# Out:
#                                      set             slug  \
# 0    L.A. County Neighborhoods (Current)            acton
# 1    L.A. County Neighborhoods (Current)  adams-normandie
# 2    L.A. County Neighborhoods (Current)     agoura-hills
# 3    L.A. County Neighborhoods (Current)       agua-dulce
# 4    L.A. County Neighborhoods (Current)         alhambra
# ..                                   ...              ...
# 267  L.A. County Neighborhoods (Current)      willowbrook
# 268  L.A. County Neighborhoods (Current)       wilmington
# 269  L.A. County Neighborhoods (Current)   windsor-square
# 270  L.A. County Neighborhoods (Current)         winnetka
# 271  L.A. County Neighborhoods (Current)   woodland-hills
#
#                                               the_geom  \
# 0    MULTIPOLYGON (((-118.20261747920541 34.5389897...
# 1    MULTIPOLYGON (((-118.30900800000012 34.0374109...
# 2    MULTIPOLYGON (((-118.76192500000009 34.1682029...
# 3    MULTIPOLYGON (((-118.2546773959221 34.55830403...
# 4    MULTIPOLYGON (((-118.12174700000014 34.1050399...
# ..                                                 ...
# 267  MULTIPOLYGON (((-118.2300539720206 33.92809400...
# 268  MULTIPOLYGON (((-118.224761 33.82460699912682,...
# 269  MULTIPOLYGON (((-118.313709 34.076309999123666...
# 270  MULTIPOLYGON (((-118.562213 34.231502999121666...
# 271  MULTIPOLYGON (((-118.57569000000001 34.1882239...
#
#                                    kind       external_i             name  \
# 0    L.A. County Neighborhood (Current)            acton            Acton
# 1    L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# 2    L.A. County Neighborhood (Current)     agoura-hills     Agoura Hills
# 3    L.A. County Neighborhood (Current)       agua-dulce       Agua Dulce
# 4    L.A. County Neighborhood (Current)         alhambra         Alhambra
# ..                                  ...              ...              ...
# 267  L.A. County Neighborhood (Current)      willowbrook      Willowbrook
# 268  L.A. County Neighborhood (Current)       wilmington       Wilmington
# 269  L.A. County Neighborhood (Current)   windsor-square   Windsor Square
# 270  L.A. County Neighborhood (Current)         winnetka         Winnetka
# 271  L.A. County Neighborhood (Current)   woodland-hills   Woodland Hills
#
#                                             display_na       sqmi  \
# 0             Acton L.A. County Neighborhood (Current)  39.339109
# 1    Adams-Normandie L.A. County Neighborhood (Curr...   0.805350
# 2      Agoura Hills L.A. County Neighborhood (Current)   8.146760
# 3        Agua Dulce L.A. County Neighborhood (Current)  31.462632
# 4          Alhambra L.A. County Neighborhood (Current)   7.623814
# ..                                                 ...        ...
# 267     Willowbrook L.A. County Neighborhood (Current)   3.766361
# 268      Wilmington L.A. County Neighborhood (Current)   9.141293
# 269  Windsor Square L.A. County Neighborhood (Current)   0.683464
# 270        Winnetka L.A. County Neighborhood (Current)   4.777241
# 271  Woodland Hills L.A. County Neighborhood (Current)  14.768310
#
#                     type  name_1  slug_1    latitude  longitude  \
# 0    unincorporated-area     NaN     NaN -118.169810  34.497355
# 1      segment-of-a-city     NaN     NaN -118.300208  34.031461
# 2        standalone-city     NaN     NaN -118.759885  34.146736
# 3    unincorporated-area     NaN     NaN -118.317104  34.504927
# 4        standalone-city     NaN     NaN -118.136512  34.085539
# ..                   ...     ...     ...         ...        ...
# 267  unincorporated-area     NaN     NaN -118.252312  33.915711
# 268    segment-of-a-city     NaN     NaN -118.259187  33.791294
# 269    segment-of-a-city     NaN     NaN -118.319909  34.069108
# 270    segment-of-a-city     NaN     NaN -118.575220  34.210459
# 271    segment-of-a-city     NaN     NaN -118.615217  34.159409
#
#                                           location
# 0    POINT(34.497355239240846 -118.16981019229348)
# 1    POINT(34.031461499124156 -118.30020800000011)
# 2    POINT(34.146736499122795 -118.75988450000015)
# 3     POINT(34.504926999796837 -118.3171036690717)
# 4    POINT(34.085538999123571 -118.13651200000021)
# ..                                             ...
# 267  POINT(33.915710503828592 -118.25231247908229)
# 268   POINT(33.79129350128175 -118.25918700000008)
# 269  POINT(34.069108499123722 -118.31990900000005)
# 270  POINT(34.210459499121988 -118.57521950000014)
# 271  POINT(34.159408692550485 -118.61521650000006)
#
# [272 rows x 14 columns]

# %%
la_neighborhoods_df = la_neighborhoods[["name","latitude","longitude"]]

# %%
la_neighborhoods_df
# Out:
#                 name    latitude  longitude
# 0              Acton -118.169810  34.497355
# 1    Adams-Normandie -118.300208  34.031461
# 2       Agoura Hills -118.759885  34.146736
# 3         Agua Dulce -118.317104  34.504927
# 4           Alhambra -118.136512  34.085539
# ..               ...         ...        ...
# 267      Willowbrook -118.252312  33.915711
# 268       Wilmington -118.259187  33.791294
# 269   Windsor Square -118.319909  34.069108
# 270         Winnetka -118.575220  34.210459
# 271   Woodland Hills -118.615217  34.159409
#
# [272 rows x 3 columns]

# %%
los_angeles_covid_rates.rename(columns={"City/Community":"name"}, inplace = True)
los_angeles_covid_rates
# Out:
# /Users/matthewsmorris/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                         name  Total Cases  Crude Case Rate3  \
# 85           Adams-Normandie           50               610
# 86                    Alsace           37               297
# 87   Angeles National Forest            0                 0
# 88          Angelino Heights           14               560
# 89                    Arleta          318               925
# ..                       ...          ...               ...
# 219       Wholesale District          167               462
# 220               Wilmington          360               637
# 221          Wilshire Center          298               594
# 222                 Winnetka          314               606
# 223           Woodland Hills          258               379
#
#      Adjusted Case Rate3,4 Unstable Adjusted Rate  2018 PEPS Population
# 85                     589                    NaN                  8202
# 86                     302                    NaN                 12445
# 87                       0                    NaN                    40
# 88                     614                      ^                  2502
# 89                     924                    NaN                 34370
# ..                     ...                    ...                   ...
# 219                    461                    NaN                 36129
# 220                    633                    NaN                 56487
# 221                    591                    NaN                 50170
# 222                    598                    NaN                 51786
# 223                    383                    NaN                 68055
#
# [139 rows x 6 columns]

# %%
merged_LA_data = pd.merge(la_neighborhoods_df,los_angeles_covid_rates, on="name")

# %% [markdown]
# ### The inner merge above ensures we only keep neighborhoods for which we have data in both dataframes

# %%
merged_LA_data
# Out:
#                 name    latitude  longitude  Total Cases  Crude Case Rate3  \
# 0    Adams-Normandie -118.300208  34.031461           50               610
# 1             Arleta -118.430757  34.243100          318               925
# 2    Atwater Village -118.262373  34.131066           59               402
# 3      Beverly Crest -118.423263  34.106007           17               136
# 4          Koreatown -118.304958  34.064510          274               530
# ..               ...         ...        ...          ...               ...
# 81  West Los Angeles -118.430745  34.047220          108               287
# 82          Westwood -118.440480  34.065235          141               261
# 83        Wilmington -118.259187  33.791294          360               637
# 84          Winnetka -118.575220  34.210459          314               606
# 85    Woodland Hills -118.615217  34.159409          258               379
#
#     Adjusted Case Rate3,4 Unstable Adjusted Rate  2018 PEPS Population
# 0                     589                    NaN                  8202
# 1                     924                    NaN                 34370
# 2                     394                    NaN                 14666
# 3                     135                      ^                 12525
# 4                     526                    NaN                 51693
# ..                    ...                    ...                   ...
# 81                    296                    NaN                 37636
# 82                    245                    NaN                 54109
# 83                    633                    NaN                 56487
# 84                    598                    NaN                 51786
# 85                    383                    NaN                 68055
#
# [86 rows x 8 columns]

# %%
merged_LA_data.rename(columns = {"name":"Neighborhood"}, inplace=True)

# %% [markdown]
# ### So turns out our latitude and logitude data was inverted from our source.  Fixing that.

# %%
corrected_long_lat_LA = merged_LA_data.rename(columns={"longitude":"lat", "latitude":"long"})

# %%
corrected_long_lat_LA
# Out:
#         Neighborhood        long        lat  Total Cases  Crude Case Rate3  \
# 0    Adams-Normandie -118.300208  34.031461           50               610
# 1             Arleta -118.430757  34.243100          318               925
# 2    Atwater Village -118.262373  34.131066           59               402
# 3      Beverly Crest -118.423263  34.106007           17               136
# 4          Koreatown -118.304958  34.064510          274               530
# ..               ...         ...        ...          ...               ...
# 81  West Los Angeles -118.430745  34.047220          108               287
# 82          Westwood -118.440480  34.065235          141               261
# 83        Wilmington -118.259187  33.791294          360               637
# 84          Winnetka -118.575220  34.210459          314               606
# 85    Woodland Hills -118.615217  34.159409          258               379
#
#     Adjusted Case Rate3,4 Unstable Adjusted Rate  2018 PEPS Population
# 0                     589                    NaN                  8202
# 1                     924                    NaN                 34370
# 2                     394                    NaN                 14666
# 3                     135                      ^                 12525
# 4                     526                    NaN                 51693
# ..                    ...                    ...                   ...
# 81                    296                    NaN                 37636
# 82                    245                    NaN                 54109
# 83                    633                    NaN                 56487
# 84                    598                    NaN                 51786
# 85                    383                    NaN                 68055
#
# [86 rows x 8 columns]

# %% [markdown]
# ### Pulling Foursquare Neighborhood Data: A Known Problem

# %%
CLIENT_ID = 'REDACTED' # your Foursquare ID
CLIENT_SECRET = 'REDACTED' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: LNP5VXIAT3ARBHP2HZONJKFBZCU2Z2D4CREQEGDSIH3WGRJT
# CLIENT_SECRET:R55Q3YNOJ3BH4CDXBYVKJSQ2JEYS2KUWYOTWCWJ0NVHFRTMB

# %%
latitude = 34.052235
longitude = -118.243683
la = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, neighborhood, covid_rate in zip(corrected_long_lat_LA['lat'], corrected_long_lat_LA['long'], corrected_long_lat_LA['Neighborhood'], (corrected_long_lat_LA["Total Cases"]/corrected_long_lat_LA["2018 PEPS Population"])*100):
    label = '{}, {}, {}, {}'.format(neighborhood, covid_rate, lat, lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(la)  
    
la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7aa4cdc1800c4adabfd6b1720bb48a94%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7aa4cdc1800c4adabfd6b1720bb48a94%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7aa4cdc1800c4adabfd6b1720bb48a94%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7aa4cdc1800c4adabfd6b1720bb48a94%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.052235%2C%20-118.243683%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Randomly pick West LA for lat/long

# %%
west_la_latitude = corrected_long_lat_LA.loc[81,'lat']
west_la_longitude = corrected_long_lat_LA.loc[81, 'long']

url = "https://api.foursquare.com/v2/venues/explore"

params = dict(
client_id= CLIENT_ID,
client_secret= CLIENT_SECRET,
v='20180323',
ll='{},{}'.format(west_la_latitude,west_la_longitude),
radius = 500,
limit=100
)

# %% [markdown]
# ### Boom, some data on West LA!

# %%
import requests
import json

results = requests.get(url, params).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '602c7ac8d8ba7776df7c237a'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Westside',
#   'headerFullLocation': 'Westside, Los Angeles',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 31,
#   'suggestedBounds': {'ne': {'lat': 34.051720503623926,
#     'lng': -118.42532363318354},
#    'sw': {'lat': 34.04272049462392, 'lng': -118.43616536681647}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49fb4ccaf964a520326e1fe3',
#        'name': 'California Chicken Cafe',
#        'contact': {},
#        'location': {'address': '2005 Westwood Blvd',
#         'crossStreet': 'at La Grange Ave',
#         'lat': 34.04643399855932,
#         'lng': -118.43412753915116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04643399855932,
#           'lng': -118.43412753915116},
#          {'label': 'entrance', 'lat': 34.04641, 'lng': -118.434081}],
#         'distance': 324,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2005 Westwood Blvd (at La Grange Ave)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-49fb4ccaf964a520326e1fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511023e0e4b036b56d8bb1ad',
#        'name': 'The West End: Craft Cocktail Bar and Neighborhood Kitchen',
#        'contact': {},
#        'location': {'address': '2116-B Westwood Blvd',
#         'crossStreet': 'Mississippi',
#         'lat': 34.045004268534434,
#         'lng': -118.43238617834248,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.045004268534434,
#           'lng': -118.43238617834248}],
#         'distance': 289,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2116-B Westwood Blvd (Mississippi)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-511023e0e4b036b56d8bb1ad-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56343849498ef882f005a3ef',
#        'name': 'Tacos Tu Madre',
#        'contact': {},
#        'location': {'address': '1945 1/2 Westwood Blvd',
#         'lat': 34.04756160769053,
#         'lng': -118.43498287421569,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04756160769053,
#           'lng': -118.43498287421569}],
#         'distance': 392,
#         'postalCode': '90025',
#         'cc': 'US',
#         'neighborhood': 'Westside',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1945 1/2 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-56343849498ef882f005a3ef-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '539bc293498ef219413bf685',
#        'name': 'Zuma Kitchen',
#        'contact': {},
#        'location': {'address': '1924 Westwood Blvd.',
#         'lat': 34.04761135420491,
#         'lng': -118.43475917076218,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04761135420491,
#           'lng': -118.43475917076218}],
#         'distance': 372,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1924 Westwood Blvd.',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-539bc293498ef219413bf685-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a085d5cf964a520b7731fe3',
#        'name': 'The Bigg Chill',
#        'contact': {},
#        'location': {'address': '10850 W Olympic Blvd',
#         'crossStreet': 'at Westwood Blvd',
#         'lat': 34.04374695866345,
#         'lng': -118.43141644501945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04374695866345,
#           'lng': -118.43141644501945},
#          {'label': 'entrance', 'lat': 34.043757, 'lng': -118.431392}],
#         'distance': 391,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['10850 W Olympic Blvd (at Westwood Blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a085d5cf964a520b7731fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49f34c0cf964a520846a1fe3',
#        'name': 'Poquito Mas',
#        'contact': {},
#        'location': {'address': '2215 Westwood Blvd',
#         'crossStreet': 'at W Olympic Blvd',
#         'lat': 34.04323919710888,
#         'lng': -118.43171181559435,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04323919710888,
#           'lng': -118.43171181559435}],
#         'distance': 452,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2215 Westwood Blvd (at W Olympic Blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-49f34c0cf964a520846a1fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a01f30cf964a52015711fe3',
#        'name': 'Pitfire Pizza',
#        'contact': {},
#        'location': {'address': '2018 Westwood Blvd',
#         'lat': 34.04650187279908,
#         'lng': -118.43388014228479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04650187279908,
#           'lng': -118.43388014228479},
#          {'label': 'entrance', 'lat': 34.046454, 'lng': -118.433791}],
#         'distance': 300,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2018 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2382478',
#         'url': 'https://www.grubhub.com/restaurant/pitfire-pizza---west-la-2018-westwood-blvd-los-angeles/2382478?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2382478',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94161795'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a01f30cf964a52015711fe3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afa38c5f964a520661722e3',
#        'name': 'Feast From the East',
#        'contact': {},
#        'location': {'address': '1949 Westwood Blvd',
#         'lat': 34.047487863659114,
#         'lng': -118.43484501010771,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.047487863659114,
#           'lng': -118.43484501010771},
#          {'label': 'entrance', 'lat': 34.047383, 'lng': -118.434918}],
#         'distance': 379,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1949 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '70135',
#         'url': 'https://www.grubhub.com/restaurant/feast-from-the-east-1949-westwood-blvd-los-angeles/70135?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=70135',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32893595'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4afa38c5f964a520661722e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c0f325498e4e6ed9fdb794',
#        'name': 'Taste of Tehran',
#        'contact': {},
#        'location': {'address': '1915 Westwood Blvd',
#         'lat': 34.047816974491084,
#         'lng': -118.43516139893934,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.047816974491084,
#           'lng': -118.43516139893934},
#          {'label': 'entrance', 'lat': 34.047748, 'lng': -118.435233}],
#         'distance': 412,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1915 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f7',
#          'name': 'Persian Restaurant',
#          'pluralName': 'Persian Restaurants',
#          'shortName': 'Persian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '546026',
#         'url': 'https://www.grubhub.com/restaurant/taste-of-tehran-1915-westwood-blvd-los-angeles/546026?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=546026',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-51c0f325498e4e6ed9fdb794-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54583e3b498ec0587be866ae',
#        'name': 'Necco',
#        'contact': {},
#        'location': {'address': '1929 Westwood Blvd',
#         'lat': 34.04763989678694,
#         'lng': -118.43500363657121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04763989678694,
#           'lng': -118.43500363657121}],
#         'distance': 395,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1929 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-54583e3b498ec0587be866ae-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bda0e442a3a0f470889a9b6',
#        'name': 'California Fresh',
#        'contact': {},
#        'location': {'address': '2000 Westwood Blvd',
#         'crossStreet': 'at La Grange Ave',
#         'lat': 34.04670018311597,
#         'lng': -118.43402423256443,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04670018311597,
#           'lng': -118.43402423256443},
#          {'label': 'entrance', 'lat': 34.046657, 'lng': -118.433964}],
#         'distance': 308,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2000 Westwood Blvd (at La Grange Ave)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '260485',
#         'url': 'https://www.grubhub.com/restaurant/california-fresh-pizza-2000-westwood-blvd-los-angeles/260485?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=260485',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4bda0e442a3a0f470889a9b6-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b09cb06f964a520b51d23e3',
#        'name': 'Pink Orchid',
#        'contact': {},
#        'location': {'address': '1927 Westwood Blvd',
#         'lat': 34.047752474371464,
#         'lng': -118.43511409225731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.047752474371464,
#           'lng': -118.43511409225731},
#          {'label': 'entrance', 'lat': 34.047464, 'lng': -118.434987}],
#         'distance': 407,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1927 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b09cb06f964a520b51d23e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b731a16f964a520809b2de3',
#        'name': 'That Pizza Place',
#        'contact': {},
#        'location': {'address': '2180 Westwood Blvd',
#         'crossStreet': 'at Olympic Blvd.',
#         'lat': 34.04447071625023,
#         'lng': -118.43181928626117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04447071625023,
#           'lng': -118.43181928626117}],
#         'distance': 321,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Westwood Blvd (at Olympic Blvd.)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '80875',
#         'url': 'https://www.grubhub.com/restaurant/that-pizza-place-2180-westwood-blvd-ste-1s-los-angeles/80875?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=80875',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b731a16f964a520809b2de3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe4fe96a93b7138b14ebd2',
#        'name': 'Hot Rod LA',
#        'contact': {},
#        'location': {'address': '2253 Westwood Blvd',
#         'lat': 34.04306418815942,
#         'lng': -118.43113647758453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04306418815942,
#           'lng': -118.43113647758453},
#          {'label': 'entrance', 'lat': 34.043022, 'lng': -118.431159}],
#         'distance': 464,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2253 Westwood Blvd',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4bbe4fe96a93b7138b14ebd2-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512ee448e4b0f1afa44fc833',
#        'name': 'The Room Sushi Bar',
#        'contact': {},
#        'location': {'lat': 34.04845260626544,
#         'lng': -118.43552687243827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04845260626544,
#           'lng': -118.43552687243827}],
#         'distance': 461,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Los Angeles, CA 90025', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '281407',
#         'url': 'https://www.grubhub.com/restaurant/the-room-sushi-bar-1884-westwood-blvd-los-angeles/281407?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=281407',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-512ee448e4b0f1afa44fc833-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a10610ef964a520b1761fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '1898 Westwood Blvd',
#         'lat': 34.04832185790228,
#         'lng': -118.4354026918054,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04832185790228,
#           'lng': -118.4354026918054}],
#         'distance': 446,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Westwood',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1898 Westwood Blvd',
#          'Westwood, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a10610ef964a520b1761fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7eb8cdf964a52022fb2fe3',
#        'name': "Bueller's Bagels",
#        'contact': {},
#        'location': {'address': '10840 W Olympic Blvd',
#         'crossStreet': 'at Westwood Blvd',
#         'lat': 34.04389343566174,
#         'lng': -118.43111332546437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04389343566174,
#           'lng': -118.43111332546437},
#          {'label': 'entrance', 'lat': 34.043914, 'lng': -118.431133}],
#         'distance': 371,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['10840 W Olympic Blvd (at Westwood Blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1301487',
#         'url': 'https://www.grubhub.com/restaurant/buellers-bagels-10840-w-olympic-blvd-los-angeles/1301487?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1301487',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b7eb8cdf964a52022fb2fe3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a03369df964a5209d711fe3',
#        'name': "Penguin's Frozen Yogurt",
#        'contact': {},
#        'location': {'address': '2180 Westwood Blvd',
#         'crossStreet': 'Olympic Blvd.',
#         'lat': 34.04437754379718,
#         'lng': -118.43197607119006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04437754379718,
#           'lng': -118.43197607119006}],
#         'distance': 336,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Westwood Blvd (Olympic Blvd.)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'shortName': 'Yogurt',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a03369df964a5209d711fe3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5a5d1ef964a52035c028e3',
#        'name': "Peet's Coffee & Tea",
#        'contact': {},
#        'location': {'address': '1854 Westwood Blvd.,',
#         'lat': 34.04879,
#         'lng': -118.435754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04879,
#           'lng': -118.435754},
#          {'label': 'entrance', 'lat': 34.049066, 'lng': -118.435776}],
#         'distance': 493,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1854 Westwood Blvd.,',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359394650'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b5a5d1ef964a52035c028e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b88998bf964a5208a0332e3',
#        'name': 'Pastina Trattoria',
#        'contact': {},
#        'location': {'address': '2260 Westwood Blvd',
#         'lat': 34.043039185822096,
#         'lng': -118.43084482300034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.043039185822096,
#           'lng': -118.43084482300034},
#          {'label': 'entrance', 'lat': 34.043038, 'lng': -118.430843}],
#         'distance': 465,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2260 Westwood Blvd',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '305316',
#         'url': 'https://www.grubhub.com/restaurant/pastina-trattoria-2260-westwood-blvd-los-angeles/305316?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305316',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '514325479'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b88998bf964a5208a0332e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b9f8cf964a520b50b29e3',
#        'name': 'The Vitamin Shoppe',
#        'contact': {},
#        'location': {'address': '1901 Westwood Blvd',
#         'crossStreet': 'at Missouri Ave',
#         'lat': 34.0477753,
#         'lng': -118.43552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0477753,
#           'lng': -118.43552},
#          {'label': 'entrance', 'lat': 34.047892, 'lng': -118.435399}],
#         'distance': 444,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1901 Westwood Blvd (at Missouri Ave)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4cd',
#          'name': 'Supplement Shop',
#          'pluralName': 'Supplement Shops',
#          'shortName': 'Supplement Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b5b9f8cf964a520b50b29e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6613c4f964a52061122be3',
#        'name': 'Baskin-Robbins',
#        'contact': {},
#        'location': {'address': '2215 Westwood Blvd',
#         'crossStreet': 'at Olympic Blvd',
#         'lat': 34.04324859695184,
#         'lng': -118.43179810090996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04324859695184,
#           'lng': -118.43179810090996},
#          {'label': 'entrance', 'lat': 34.04319, 'lng': -118.431587}],
#         'distance': 452,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2215 Westwood Blvd (at Olympic Blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b6613c4f964a52061122be3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '41293380f964a520650c1fe3',
#        'name': 'Philly West',
#        'contact': {},
#        'location': {'address': '1870 Westwood Blvd',
#         'crossStreet': 'at Santa Monica',
#         'lat': 34.04864139608206,
#         'lng': -118.43561715827202,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04864139608206,
#           'lng': -118.43561715827202},
#          {'label': 'entrance', 'lat': 34.048639, 'lng': -118.435674}],
#         'distance': 476,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1870 Westwood Blvd (at Santa Monica)',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-41293380f964a520650c1fe3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bba352f3db7b713e008239a',
#        'name': 'WW (Weight Watchers)',
#        'contact': {},
#        'location': {'address': '2876 Cochran St,Ste 5',
#         'lat': 34.044297695830586,
#         'lng': -118.43163305547458,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.044297695830586,
#           'lng': -118.43163305547458}],
#         'distance': 335,
#         'postalCode': '93065',
#         'cc': 'US',
#         'city': 'Simi Valley',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2876 Cochran St,Ste 5',
#          'Simi Valley, CA 93065',
#          'United States']},
#        'categories': [{'id': '590a0744340a5803fd8508c3',
#          'name': 'Weight Loss Center',
#          'pluralName': 'Weight Loss Centers',
#          'shortName': 'Weight Loss Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4bba352f3db7b713e008239a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556bab2e498e321bfa21137a',
#        'name': 'PURE Pressed LA',
#        'contact': {},
#        'location': {'address': '10844 W Olympic Blvd',
#         'crossStreet': 'Westwood blvd',
#         'lat': 34.04405245252325,
#         'lng': -118.43129329323006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04405245252325,
#           'lng': -118.43129329323006}],
#         'distance': 356,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['10844 W Olympic Blvd (Westwood blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1259279',
#         'url': 'https://www.grubhub.com/restaurant/pure-pressed-juice-10844-w-olympic-blvd-los-angeles/1259279?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1259279',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-556bab2e498e321bfa21137a-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a6b83cff964a520e9ce1fe3',
#        'name': 'Petco',
#        'contact': {},
#        'location': {'address': '1873 Westwood Blvd',
#         'lat': 34.04832044636836,
#         'lng': -118.43564731706294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04832044636836,
#           'lng': -118.43564731706294},
#          {'label': 'entrance', 'lat': 34.048402, 'lng': -118.43583}],
#         'distance': 468,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1873 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a6b83cff964a520e9ce1fe3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c3860c498e192398b47f13',
#        'name': 'Panda Express',
#        'contact': {},
#        'location': {'address': '2011 Westwood Blvd',
#         'lat': 34.046232844308925,
#         'lng': -118.43398503409851,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.046232844308925,
#           'lng': -118.43398503409851}],
#         'distance': 318,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2011 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-57c3860c498e192398b47f13-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4add31c8f964a5208b6421e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '2215 Westwood Blvd',
#         'crossStreet': 'at Olympic Blvd',
#         'lat': 34.04322916896218,
#         'lng': -118.43161655490833,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04322916896218,
#           'lng': -118.43161655490833},
#          {'label': 'entrance', 'lat': 34.04319, 'lng': -118.431587}],
#         'distance': 451,
#         'postalCode': '90064',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2215 Westwood Blvd (at Olympic Blvd)',
#          'Los Angeles, CA 90064',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4add31c8f964a5208b6421e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec835409adf9c7bf3f1ba92',
#        'name': 'Chase Bank',
#        'contact': {},
#        'location': {'address': '10700 Santa Monica Blvd Ste 100',
#         'lat': 34.0513617,
#         'lng': -118.4324255,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0513617,
#           'lng': -118.4324255}],
#         'distance': 486,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['10700 Santa Monica Blvd Ste 100',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ec835409adf9c7bf3f1ba92-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d39824498ed659529aac25',
#        'name': 'Farsi Cafe',
#        'contact': {},
#        'location': {'address': '1916 Westwood Blvd',
#         'lat': 34.0479465,
#         'lng': -118.4349526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0479465,
#           'lng': -118.4349526}],
#         'distance': 396,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1916 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f7',
#          'name': 'Persian Restaurant',
#          'pluralName': 'Persian Restaurants',
#          'shortName': 'Persian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '560152',
#         'url': 'https://www.grubhub.com/restaurant/farsi-cafe-1916-westwood-blvd-los-angeles/560152?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=560152',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94366147'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-51d39824498ed659529aac25-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2c9c95f964a5201dc824e3',
#        'name': 'Byblos',
#        'contact': {},
#        'location': {'address': '1964 Westwood Blvd',
#         'lat': 34.04727952613045,
#         'lng': -118.43458082150845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04727952613045,
#           'lng': -118.43458082150845}],
#         'distance': 353,
#         'postalCode': '90025',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1964 Westwood Blvd',
#          'Los Angeles, CA 90025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b2c9c95f964a5201dc824e3-30'}]}]}}
